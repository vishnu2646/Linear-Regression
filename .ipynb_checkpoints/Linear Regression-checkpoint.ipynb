# %%
import pandas as pd

# %%
df = pd.read_csv('lung_cancer_examples.csv')

# %%
df.head(10)
# Out:
#         Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0       John         Wick   35       3      5       4       1
# 1       John  Constantine   27      20      2       5       1
# 2     Camela     Anderson   30       0      5       2       0
# 3       Alex       Telles   28       0      8       1       0
# 4      Diego     Maradona   68       4      5       6       1
# 5  Cristiano      Ronaldo   34       0     10       0       0
# 6     Mihail          Tal   58      15     10       0       0
# 7      Kathy        Bates   22      12      5       2       0
# 8     Nicole       Kidman   45       2      6       0       0
# 9        Ray      Milland   52      18      4       5       1

# %%
# %matplotlib inline
import seaborn as sns

# %%
sns.pairplot(df,x_vars=['Age','Smokes','AreaQ','Alkhol'],y_vars='Result',height=7,aspect=0.7,kind='reg')

# %%
feature_cols = ['Age','Smokes','AreaQ','Alkhol']
X = df[feature_cols]

# %%
Y = df['Result']

# %% [markdown]
# # Train Dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_test,X_train,Y_test,Y_train = train_test_split(X,Y,random_state=1)

# %%
X_train.shape
# Out:
# (15, 4)

# %%
Y_train.shape
# Out:
# (15,)

# %%
X_test.shape,Y_test.shape
# Out:
# ((44, 4), (44,))

# %% [markdown]
# # Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
a = LinearRegression()
a.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
a.intercept_
# Out:
# -0.30785433013104957

# %%
a.coef_
# Out:
# array([ 0.01354157,  0.0093787 , -0.04915038,  0.08300373])
